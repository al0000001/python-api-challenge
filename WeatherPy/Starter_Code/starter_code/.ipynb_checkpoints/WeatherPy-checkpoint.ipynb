# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 622

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
      
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(query_url + city).json()  

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat =  city_weather['coord']['lat']
        city_lng =  city_weather['coord']['lon']
        city_max_temp =  city_weather['main']['temp_max']
        city_humidity =  city_weather['main']['humidity']
        city_clouds =  city_weather['clouds']["all"]
        city_wind =  city_weather['wind']['speed']
        city_country =  city_weather['sys']['country']
        city_date =  city_weather['sys']['sunrise']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kysyl-syr
# Processing Record 2 of Set 1 | nemuro
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | namibe
# Processing Record 7 of Set 1 | porbandar
# Processing Record 8 of Set 1 | bilma
# Processing Record 9 of Set 1 | guarapari
# Processing Record 10 of Set 1 | santiago del estero
# Processing Record 11 of Set 1 | nsanje
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | souillac
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | college
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | olden
# Processing Record 18 of Set 1 | arlit
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | labuhan
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | mumford
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | ust-uda
# Processing Record 31 of Set 1 | san jose iturbide
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | twin falls
# Processing Record 40 of Set 1 | bobo dioulasso
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | adrar
# Processing Record 44 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 1 | sao joao da barra
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | manaure
# Processing Record 49 of Set 1 | kiama
# Processing Record 50 of Set 1 | sola
# Processing Record 0 of Set 2 | luderitz
# Processing Record 1 of Set 2 | bestobe
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | fare
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | alice town
# Processing Record 6 of Set 2 | limbang
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | kholodnyy
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | christchurch
# Processing Record 14 of Set 2 | aklavik
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | pangnirtung
# Processing Record 17 of Set 2 | starosubkhangulovo
# Processing Record 18 of Set 2 | itoman
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | cilaos
# Processing Record 21 of Set 2 | balkanabat
# Processing Record 22 of Set 2 | trojes
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | samarinda
# Processing Record 25 of Set 2 | chute-aux-outardes
# Processing Record 26 of Set 2 | gazojak
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | cabedelo
# Processing Record 30 of Set 2 | linxia
# Processing Record 31 of Set 2 | aguimes
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | grindavik
# Processing Record 34 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 2 | yokadouma
# Processing Record 36 of Set 2 | codrington
# Processing Record 37 of Set 2 | puerto madryn
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | hatillo
# Processing Record 40 of Set 2 | chizhou
# Processing Record 41 of Set 2 | isangel
# Processing Record 42 of Set 2 | boende
# Processing Record 43 of Set 2 | vila franca do campo
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | ushuaia
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | yerbogachen
# Processing Record 49 of Set 2 | kahului
# Processing Record 0 of Set 3 | durango
# Processing Record 1 of Set 3 | burica
# City not found. Skipping...
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | kisangani
# Processing Record 4 of Set 3 | calama
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | provideniya
# Processing Record 9 of Set 3 | capao bonito
# Processing Record 10 of Set 3 | lexington park
# Processing Record 11 of Set 3 | hambantota
# Processing Record 12 of Set 3 | gurupa
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | tuatapere
# Processing Record 15 of Set 3 | honiara
# Processing Record 16 of Set 3 | deputatskiy
# Processing Record 17 of Set 3 | margate
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | fort nelson
# Processing Record 20 of Set 3 | tiznit
# Processing Record 21 of Set 3 | nichinan
# Processing Record 22 of Set 3 | alyangula
# Processing Record 23 of Set 3 | jinchang
# Processing Record 24 of Set 3 | basco
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | tautira
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | geraldton
# Processing Record 29 of Set 3 | xining
# Processing Record 30 of Set 3 | cape town
# Processing Record 31 of Set 3 | viedma
# Processing Record 32 of Set 3 | ubinskoye
# Processing Record 33 of Set 3 | maloy
# Processing Record 34 of Set 3 | mangan
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 3 | winnemucca
# Processing Record 39 of Set 3 | kasongo-lunda
# Processing Record 40 of Set 3 | areosa
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | progreso
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | bafoulabe
# Processing Record 45 of Set 3 | severo-kurilsk
# Processing Record 46 of Set 3 | puksoozero
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | surat
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 0 of Set 4 | jumla
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | ravar
# Processing Record 3 of Set 4 | boa vista
# Processing Record 4 of Set 4 | sioux lookout
# Processing Record 5 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 4 | muyezerskiy
# Processing Record 7 of Set 4 | duluth
# Processing Record 8 of Set 4 | sorland
# Processing Record 9 of Set 4 | ajdabiya
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | hoa binh
# Processing Record 12 of Set 4 | chesma
# Processing Record 13 of Set 4 | cherskiy
# Processing Record 14 of Set 4 | sedhiou
# Processing Record 15 of Set 4 | barranca
# Processing Record 16 of Set 4 | saint anthony
# Processing Record 17 of Set 4 | puri
# Processing Record 18 of Set 4 | clyde river
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | rumphi
# Processing Record 21 of Set 4 | bosaso
# Processing Record 22 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 4 | bonthe
# Processing Record 24 of Set 4 | wellington
# Processing Record 25 of Set 4 | belaya gora
# Processing Record 26 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 27 of Set 4 | vao
# Processing Record 28 of Set 4 | san marcos de colon
# Processing Record 29 of Set 4 | port blair
# Processing Record 30 of Set 4 | capelinha
# Processing Record 31 of Set 4 | saldanha
# Processing Record 32 of Set 4 | la rioja
# Processing Record 33 of Set 4 | salvador
# Processing Record 34 of Set 4 | hofn
# Processing Record 35 of Set 4 | santa maria
# Processing Record 36 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 38 of Set 4 | kytmanovo
# Processing Record 39 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 4 | broome
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | klaksvik
# Processing Record 43 of Set 4 | almetyevsk
# Processing Record 44 of Set 4 | praia
# Processing Record 45 of Set 4 | carnarvon
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | pevek
# Processing Record 49 of Set 4 | toowoomba
# Processing Record 0 of Set 5 | norman wells
# Processing Record 1 of Set 5 | muzhi
# Processing Record 2 of Set 5 | longyearbyen
# Processing Record 3 of Set 5 | cananea
# Processing Record 4 of Set 5 | tual
# Processing Record 5 of Set 5 | ailigandi
# Processing Record 6 of Set 5 | chokurdakh
# Processing Record 7 of Set 5 | tobane
# Processing Record 8 of Set 5 | khor
# Processing Record 9 of Set 5 | bereda
# Processing Record 10 of Set 5 | lerwick
# Processing Record 11 of Set 5 | vestmannaeyjar
# Processing Record 12 of Set 5 | alpatovo
# Processing Record 13 of Set 5 | santana do livramento
# Processing Record 14 of Set 5 | hvide sande
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | gobabis
# Processing Record 17 of Set 5 | prabumulih
# Processing Record 18 of Set 5 | tarakan
# Processing Record 19 of Set 5 | thaton
# Processing Record 20 of Set 5 | dhidhdhoo
# Processing Record 21 of Set 5 | bredasdorp
# Processing Record 22 of Set 5 | dali
# Processing Record 23 of Set 5 | skegness
# Processing Record 24 of Set 5 | port hardy
# Processing Record 25 of Set 5 | farah
# Processing Record 26 of Set 5 | varhaug
# Processing Record 27 of Set 5 | palu
# Processing Record 28 of Set 5 | turukhansk
# Processing Record 29 of Set 5 | katsuura
# Processing Record 30 of Set 5 | akhaldaba
# Processing Record 31 of Set 5 | santa rosa
# Processing Record 32 of Set 5 | mufulira
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | jaipur hat
# City not found. Skipping...
# Processing Record 35 of Set 5 | polunochnoye
# Processing Record 36 of Set 5 | nadym
# Processing Record 37 of Set 5 | south lake tahoe
# Processing Record 38 of Set 5 | ternate
# Processing Record 39 of Set 5 | dickson
# Processing Record 40 of Set 5 | cerveteri
# Processing Record 41 of Set 5 | cap malheureux
# Processing Record 42 of Set 5 | bubaque
# Processing Record 43 of Set 5 | gazimurskiy zavod
# Processing Record 44 of Set 5 | xichang
# Processing Record 45 of Set 5 | san quintin
# Processing Record 46 of Set 5 | chiredzi
# Processing Record 47 of Set 5 | avera
# Processing Record 48 of Set 5 | sampit
# Processing Record 49 of Set 5 | naze
# Processing Record 0 of Set 6 | hongjiang
# Processing Record 1 of Set 6 | borama
# City not found. Skipping...
# Processing Record 2 of Set 6 | waspan
# Processing Record 3 of Set 6 | lishui
# Processing Record 4 of Set 6 | narsaq
# Processing Record 5 of Set 6 | maniitsoq
# Processing Record 6 of Set 6 | lasa
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | benguela
# Processing Record 9 of Set 6 | sandnessjoen
# Processing Record 10 of Set 6 | lufilufi
# Processing Record 11 of Set 6 | chifeng
# Processing Record 12 of Set 6 | raton
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | kangaatsiaq
# Processing Record 15 of Set 6 | grong
# Processing Record 16 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 17 of Set 6 | sao felix do xingu
# Processing Record 18 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 6 | khorramshahr
# Processing Record 20 of Set 6 | canchungo
# Processing Record 21 of Set 6 | kuhestan
# City not found. Skipping...
# Processing Record 22 of Set 6 | taoudenni
# Processing Record 23 of Set 6 | karratha
# Processing Record 24 of Set 6 | srednekolymsk
# Processing Record 25 of Set 6 | moose factory
# Processing Record 26 of Set 6 | athabasca
# Processing Record 27 of Set 6 | lagoa
# Processing Record 28 of Set 6 | rudbar
# Processing Record 29 of Set 6 | umm kaddadah
# Processing Record 30 of Set 6 | anadyr
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | baza
# Processing Record 33 of Set 6 | sweetwater
# Processing Record 34 of Set 6 | iralaya
# Processing Record 35 of Set 6 | san ignacio
# Processing Record 36 of Set 6 | southbridge
# Processing Record 37 of Set 6 | necochea
# Processing Record 38 of Set 6 | oranjemund
# Processing Record 39 of Set 6 | chimore
# Processing Record 40 of Set 6 | doune
# Processing Record 41 of Set 6 | ergani
# Processing Record 42 of Set 6 | vila velha
# Processing Record 43 of Set 6 | omsukchan
# Processing Record 44 of Set 6 | riyadh
# Processing Record 45 of Set 6 | samarai
# Processing Record 46 of Set 6 | chimoio
# Processing Record 47 of Set 6 | kutum
# Processing Record 48 of Set 6 | ostrovnoy
# Processing Record 49 of Set 6 | jiangkou
# Processing Record 0 of Set 7 | prado
# Processing Record 1 of Set 7 | wawa
# Processing Record 2 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 3 of Set 7 | marawi
# Processing Record 4 of Set 7 | itarema
# Processing Record 5 of Set 7 | hamilton
# Processing Record 6 of Set 7 | mindelo
# Processing Record 7 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 7 | sooke
# Processing Record 9 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 7 | revelstoke
# Processing Record 11 of Set 7 | makakilo city
# Processing Record 12 of Set 7 | ningan
# City not found. Skipping...
# Processing Record 13 of Set 7 | alta floresta
# Processing Record 14 of Set 7 | qostanay
# Processing Record 15 of Set 7 | nikolskoye
# Processing Record 16 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 7 | arrecife
# Processing Record 18 of Set 7 | ape
# Processing Record 19 of Set 7 | camacupa
# Processing Record 20 of Set 7 | swift current
# Processing Record 21 of Set 7 | balaipungut
# Processing Record 22 of Set 7 | yuancheng
# Processing Record 23 of Set 7 | saskylakh
# Processing Record 24 of Set 7 | sisimiut
# Processing Record 25 of Set 7 | vanimo
# Processing Record 26 of Set 7 | faanui
# Processing Record 27 of Set 7 | kruisfontein
# Processing Record 28 of Set 7 | jacareacanga
# Processing Record 29 of Set 7 | severobaykalsk
# Processing Record 30 of Set 7 | fairbanks
# Processing Record 31 of Set 7 | oron
# Processing Record 32 of Set 7 | gazli
# Processing Record 33 of Set 7 | upernavik
# Processing Record 34 of Set 7 | grand-santi
# Processing Record 35 of Set 7 | agirish
# Processing Record 36 of Set 7 | porto nacional
# Processing Record 37 of Set 7 | hasaki
# Processing Record 38 of Set 7 | mundo nuevo
# Processing Record 39 of Set 7 | nara
# Processing Record 40 of Set 7 | berlevag
# Processing Record 41 of Set 7 | nizhniy baskunchak
# Processing Record 42 of Set 7 | mananjary
# Processing Record 43 of Set 7 | chapada dos guimaraes
# Processing Record 44 of Set 7 | egvekinot
# Processing Record 45 of Set 7 | berdigestyakh
# Processing Record 46 of Set 7 | chisinau
# Processing Record 47 of Set 7 | evensk
# Processing Record 48 of Set 7 | seto
# Processing Record 49 of Set 7 | hirara
# Processing Record 0 of Set 8 | husavik
# Processing Record 1 of Set 8 | kidal
# Processing Record 2 of Set 8 | ust-ilimsk
# Processing Record 3 of Set 8 | khandyga
# Processing Record 4 of Set 8 | klyuchevskiy
# Processing Record 5 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 6 of Set 8 | sorong
# Processing Record 7 of Set 8 | flinders
# Processing Record 8 of Set 8 | sambava
# Processing Record 9 of Set 8 | uyuni
# Processing Record 10 of Set 8 | langxiang
# Processing Record 11 of Set 8 | rincon
# Processing Record 12 of Set 8 | glendive
# Processing Record 13 of Set 8 | newnan
# Processing Record 14 of Set 8 | tete
# Processing Record 15 of Set 8 | hami
# Processing Record 16 of Set 8 | kamaishi
# Processing Record 17 of Set 8 | victoria point
# Processing Record 18 of Set 8 | batagay
# Processing Record 19 of Set 8 | mildura
# Processing Record 20 of Set 8 | popondetta
# Processing Record 21 of Set 8 | bathsheba
# Processing Record 22 of Set 8 | oxelosund
# Processing Record 23 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 24 of Set 8 | srandakan
# Processing Record 25 of Set 8 | atbasar
# Processing Record 26 of Set 8 | urusha
# Processing Record 27 of Set 8 | kuruman
# Processing Record 28 of Set 8 | chumikan
# Processing Record 29 of Set 8 | lisakovsk
# Processing Record 30 of Set 8 | ji-parana
# City not found. Skipping...
# Processing Record 31 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 32 of Set 8 | komsomolskiy
# Processing Record 33 of Set 8 | tiarei
# Processing Record 34 of Set 8 | kunya
# Processing Record 35 of Set 8 | mapiripan
# Processing Record 36 of Set 8 | stornoway
# Processing Record 37 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 38 of Set 8 | nahuala
# Processing Record 39 of Set 8 | panjakent
# Processing Record 40 of Set 8 | zelenoborskiy
# Processing Record 41 of Set 8 | cidreira
# Processing Record 42 of Set 8 | helong
# Processing Record 43 of Set 8 | srostki
# Processing Record 44 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 8 | kaka
# Processing Record 46 of Set 8 | angoche
# Processing Record 47 of Set 8 | awbari
# Processing Record 48 of Set 8 | grand gaube
# Processing Record 49 of Set 8 | baruun-urt
# Processing Record 0 of Set 9 | visnes
# Processing Record 1 of Set 9 | yar-sale
# Processing Record 2 of Set 9 | jalu
# Processing Record 3 of Set 9 | nuuk
# Processing Record 4 of Set 9 | lashio
# Processing Record 5 of Set 9 | elektrenai
# Processing Record 6 of Set 9 | lazaro cardenas
# Processing Record 7 of Set 9 | price
# Processing Record 8 of Set 9 | aromashevo
# Processing Record 9 of Set 9 | batken
# Processing Record 10 of Set 9 | boguchany
# Processing Record 11 of Set 9 | okakarara
# Processing Record 12 of Set 9 | belmonte
# Processing Record 13 of Set 9 | angoram
# Processing Record 14 of Set 9 | ghanzi
# Processing Record 15 of Set 9 | leningradskiy
# Processing Record 16 of Set 9 | kigoma
# Processing Record 17 of Set 9 | shache
# Processing Record 18 of Set 9 | harbour breton
# Processing Record 19 of Set 9 | santa marta
# Processing Record 20 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 9 | ranau
# Processing Record 22 of Set 9 | tecoanapa
# Processing Record 23 of Set 9 | coquimbo
# Processing Record 24 of Set 9 | kerzhenets
# City not found. Skipping...
# Processing Record 25 of Set 9 | nakamura
# Processing Record 26 of Set 9 | kuryk
# Processing Record 27 of Set 9 | port hedland
# Processing Record 28 of Set 9 | meulaboh
# Processing Record 29 of Set 9 | montepuez
# Processing Record 30 of Set 9 | palmas
# Processing Record 31 of Set 9 | dakar
# Processing Record 32 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 33 of Set 9 | sinnamary
# Processing Record 34 of Set 9 | zeya
# Processing Record 35 of Set 9 | poum
# Processing Record 36 of Set 9 | ostersund
# Processing Record 37 of Set 9 | mount gambier
# Processing Record 38 of Set 9 | fortuna
# Processing Record 39 of Set 9 | laguna
# Processing Record 40 of Set 9 | bykovo
# Processing Record 41 of Set 9 | salalah
# Processing Record 42 of Set 9 | kalmunai
# Processing Record 43 of Set 9 | vardo
# Processing Record 44 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 9 | bluffton
# Processing Record 46 of Set 9 | sur
# Processing Record 47 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 48 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 9 | gat
# Processing Record 0 of Set 10 | zhigansk
# Processing Record 1 of Set 10 | libreville
# Processing Record 2 of Set 10 | sitka
# Processing Record 3 of Set 10 | panzhihua
# Processing Record 4 of Set 10 | paamiut
# Processing Record 5 of Set 10 | cururupu
# Processing Record 6 of Set 10 | port lincoln
# Processing Record 7 of Set 10 | puerto madero
# Processing Record 8 of Set 10 | bali
# Processing Record 9 of Set 10 | masakin
# Processing Record 10 of Set 10 | suntar
# Processing Record 11 of Set 10 | blagoyevo
# Processing Record 12 of Set 10 | marshall
# Processing Record 13 of Set 10 | saint marys
# Processing Record 14 of Set 10 | sangar
# Processing Record 15 of Set 10 | keti bandar
# Processing Record 16 of Set 10 | yoichi
# Processing Record 17 of Set 10 | bonavista
# Processing Record 18 of Set 10 | abnub
# Processing Record 19 of Set 10 | gizo
# Processing Record 20 of Set 10 | havre-saint-pierre
# Processing Record 21 of Set 10 | povenets
# Processing Record 22 of Set 10 | port macquarie
# Processing Record 23 of Set 10 | taltal
# Processing Record 24 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 10 | cardston
# Processing Record 26 of Set 10 | yefremov
# Processing Record 27 of Set 10 | zhuhai
# Processing Record 28 of Set 10 | marovoay
# Processing Record 29 of Set 10 | borgosesia
# Processing Record 30 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 10 | sirajganj
# Processing Record 32 of Set 10 | rucheng
# Processing Record 33 of Set 10 | mangrol
# Processing Record 34 of Set 10 | along
# Processing Record 35 of Set 10 | bani walid
# Processing Record 36 of Set 10 | yulara
# Processing Record 37 of Set 10 | beihai
# Processing Record 38 of Set 10 | tura
# Processing Record 39 of Set 10 | kaitangata
# Processing Record 40 of Set 10 | umm lajj
# Processing Record 41 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 10 | nanortalik
# Processing Record 43 of Set 10 | blagodatnoye
# Processing Record 44 of Set 10 | englewood
# Processing Record 45 of Set 10 | mosquera
# Processing Record 46 of Set 10 | verkhoyansk
# Processing Record 47 of Set 10 | sakakah
# Processing Record 48 of Set 10 | colares
# Processing Record 49 of Set 10 | gigmoto
# Processing Record 0 of Set 11 | lakes entrance
# Processing Record 1 of Set 11 | matagami
# Processing Record 2 of Set 11 | gbarnga
# Processing Record 3 of Set 11 | wakkanai
# Processing Record 4 of Set 11 | muravlenko
# Processing Record 5 of Set 11 | general roca
# Processing Record 6 of Set 11 | caucaia
# Processing Record 7 of Set 11 | cassia
# Processing Record 8 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 9 of Set 11 | nador
# Processing Record 10 of Set 11 | huambo
# Processing Record 11 of Set 11 | kununurra
# Processing Record 12 of Set 11 | la ronge
# Processing Record 13 of Set 11 | dongdu
# Processing Record 14 of Set 11 | novaya mayna
# Processing Record 15 of Set 11 | biograd na moru
# Processing Record 16 of Set 11 | lavrentiya
# Processing Record 17 of Set 11 | ilulissat
# Processing Record 18 of Set 11 | arroio do meio
# Processing Record 19 of Set 11 | caracollo
# Processing Record 20 of Set 11 | torbay
# Processing Record 21 of Set 11 | mega
# Processing Record 22 of Set 11 | nueve de julio
# Processing Record 23 of Set 11 | bayir
# Processing Record 24 of Set 11 | gao
# Processing Record 25 of Set 11 | huarmey
# Processing Record 26 of Set 11 | den helder
# Processing Record 27 of Set 11 | pitkyaranta
# Processing Record 28 of Set 11 | esperance
# Processing Record 29 of Set 11 | atar
# Processing Record 30 of Set 11 | alamos
# Processing Record 31 of Set 11 | mpika
# Processing Record 32 of Set 11 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 33 of Set 11 | kabo
# Processing Record 34 of Set 11 | ceres
# Processing Record 35 of Set 11 | savannah bight
# Processing Record 36 of Set 11 | divnogorsk
# Processing Record 37 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 38 of Set 11 | talnakh
# Processing Record 39 of Set 11 | san rafael
# Processing Record 40 of Set 11 | hammerfest
# Processing Record 41 of Set 11 | teeli
# Processing Record 42 of Set 11 | whitehorse
# Processing Record 43 of Set 11 | saryozek
# Processing Record 44 of Set 11 | bandarbeyla
# Processing Record 45 of Set 11 | ahipara
# Processing Record 46 of Set 11 | susanville
# Processing Record 47 of Set 11 | ratnagiri
# Processing Record 48 of Set 11 | tortoli
# Processing Record 49 of Set 11 | inuvik
# Processing Record 0 of Set 12 | callaguip
# Processing Record 1 of Set 12 | chilca
# Processing Record 2 of Set 12 | chibombo
# Processing Record 3 of Set 12 | auxerre
# Processing Record 4 of Set 12 | ouegoa
# Processing Record 5 of Set 12 | rosetta
# Processing Record 6 of Set 12 | bengkulu
# Processing Record 7 of Set 12 | filingue
# Processing Record 8 of Set 12 | kloulklubed
# Processing Record 9 of Set 12 | beterou
# Processing Record 10 of Set 12 | mnogovershinnyy
# Processing Record 11 of Set 12 | dzhebariki-khaya
# Processing Record 12 of Set 12 | lorengau
# Processing Record 13 of Set 12 | puerto escondido
# Processing Record 14 of Set 12 | otta
# Processing Record 15 of Set 12 | ovalle
# Processing Record 16 of Set 12 | luwuk
# Processing Record 17 of Set 12 | ayan
# Processing Record 18 of Set 12 | kaffrine
# Processing Record 19 of Set 12 | reconquista
# Processing Record 20 of Set 12 | merauke
# Processing Record 21 of Set 12 | jiwani
# Processing Record 22 of Set 12 | mezen
# Processing Record 23 of Set 12 | manokwari
# Processing Record 24 of Set 12 | iwaki
# Processing Record 25 of Set 12 | luanda
# Processing Record 26 of Set 12 | batemans bay
# Processing Record 27 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 12 | amapa
# Processing Record 29 of Set 12 | sechura
# Processing Record 30 of Set 12 | longyan
# Processing Record 31 of Set 12 | byron bay
# Processing Record 32 of Set 12 | aqtobe
# Processing Record 33 of Set 12 | jacmel
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | malartic
# Processing Record 36 of Set 12 | walvis bay
# Processing Record 37 of Set 12 | port augusta
# Processing Record 38 of Set 12 | waipawa
# Processing Record 39 of Set 12 | kavaratti
# Processing Record 40 of Set 12 | isla vista
# Processing Record 41 of Set 12 | abong mbang
# Processing Record 42 of Set 12 | kumluca
# Processing Record 43 of Set 12 | djambala
# Processing Record 44 of Set 12 | dunedin
# Processing Record 45 of Set 12 | sueyoshi
# Processing Record 46 of Set 12 | kuliyapitiya
# Processing Record 47 of Set 12 | fougeres
# Processing Record 48 of Set 12 | changji
# Processing Record 49 of Set 12 | san jeronimo
# Processing Record 0 of Set 13 | bom jesus
# Processing Record 1 of Set 13 | guerrero negro
# Processing Record 2 of Set 13 | bridlington
# Processing Record 3 of Set 13 | bowen
# Processing Record 4 of Set 13 | lompoc
# Processing Record 5 of Set 13 | taruma
# Processing Record 6 of Set 13 | kang
# Processing Record 7 of Set 13 | erie
# Processing Record 8 of Set 13 | suileng
# Processing Record 9 of Set 13 | kijang
# Processing Record 10 of Set 13 | taloqan
# Processing Record 11 of Set 13 | bakchar
# Processing Record 12 of Set 13 | novobirilyussy
# Processing Record 13 of Set 13 | nizhniy kuranakh
# Processing Record 14 of Set 13 | dalnerechensk
# Processing Record 15 of Set 13 | teacapan
# Processing Record 16 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 13 | pemangkat
# Processing Record 18 of Set 13 | warburg
# Processing Record 19 of Set 13 | kodinsk
# Processing Record 20 of Set 13 | skopelos
# Processing Record 21 of Set 13 | acarau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        kysyl-syr  63.8986  122.7617    -46.92       100          68
# 1           nemuro  43.3236  145.5750     -1.90        66          41
# 2  bambous virieux -20.3428   57.7575     30.14        62          75
# 3        busselton -33.6500  115.3333     19.63        54           9
# 4        jamestown  42.0970  -79.2353      1.77        72         100
#
#    Wind Speed Country        Date
# 0        1.34      RU  1672968704
# 1        4.48      JP  1672955400
# 2        6.69      MU  1672968903
# 3        9.29      AU  1672953314
# 4        1.54      US  1673009114

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              kysyl-syr  63.8986  122.7617    -46.92       100          68
# 1                 nemuro  43.3236  145.5750     -1.90        66          41
# 2        bambous virieux -20.3428   57.7575     30.14        62          75
# 3              busselton -33.6500  115.3333     19.63        54           9
# 4              jamestown  42.0970  -79.2353      1.77        72         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      RU  1672968704
# 1              4.48      JP  1672955400
# 2              6.69      MU  1672968903
# 3              9.29      AU  1672953314
# 4              1.54      US  1673009114

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

city_data_df.plot(kind="scatter", x="Lat", y="Max Temp",s=50,grid=True, figsize=(8,6),edgecolors="black",marker="o",)
# Incorporate the other graph properties

plt.title("City Max Latitude vs. Temperature (2023-01-06)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")


# Save the figure
plt.savefig("../output_data/Fig1.png")

# # Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Lat", y="Humidity",s=50,grid=True, figsize=(8,6),edgecolors="black",marker="o",)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (2023-01-06)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter", x="Lat", y="Cloudiness",s=50,grid=True, figsize=(8,6),edgecolors="black",marker="o",)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (2023-01-06)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter", x="Lat", y="Wind Speed",s=50,grid=True, figsize=(8,6),edgecolors="black",marker="o",)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Windspeed (2023-01-06)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        kysyl-syr  63.8986  122.7617    -46.92       100          68
# 1           nemuro  43.3236  145.5750     -1.90        66          41
# 4        jamestown  42.0970  -79.2353      1.77        72         100
# 6        porbandar  21.6422   69.6093     25.78        41           8
# 7            bilma  18.6853   12.9164     21.69        24          19
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      RU  1672968704
# 1              4.48      JP  1672955400
# 4              1.54      US  1673009114
# 6              1.91      IN  1672970458
# 7              3.39      NE  1672983733

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

southern_hemi_df=city_data_df.loc[city_data_df["Lat"]<0,:]
# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2            bambous virieux -20.3428   57.7575     30.14        62
# 3                  busselton -33.6500  115.3333     19.63        54
# 5                     namibe -15.1961   12.1522     23.72        68
# 8                  guarapari -20.6667  -40.4975     24.38        92
# 9        santiago del estero -27.7951  -64.2615     22.31        29
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                75        6.69      MU  1672968903
# 3                 9        9.29      AU  1672953314
# 5                73        5.84      AO  1672980432
# 8               100        0.56      BR  1672992457
# 9                71        1.68      AR  1672997276

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_n_values = northern_hemi_df['Lat']
y_n_t_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_n_values, y_n_t_values)
regress_values = x_n_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(8.5, 7))
plt.scatter(x_n_values,y_n_t_values)
plt.plot(x_n_values,regress_values,"r-")
plt.annotate(line_eq,(0,-40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

print(f"The r-value is: {rvalue}")

plt.show()
# Out:
# The r-value is: -0.8703448989812497

# %%
# Linear regression on Southern Hemisphere
x_s_values = southern_hemi_df['Lat']
y_s_t_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_s_values, y_s_t_values)
regress_values = x_s_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(8.5, 7))
plt.scatter(x_s_values,y_s_t_values)
plt.plot(x_s_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.476040371288352

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_n_values = northern_hemi_df['Lat']
y_n_h_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_n_values, y_n_h_values)
regress_values = x_n_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(8.5, 7))
plt.scatter(x_n_values,y_n_h_values)
plt.plot(x_n_values,regress_values,"r-")
plt.annotate(line_eq,(42,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.46884212372298334

# %%
# Southern Hemisphere
x_s_values = southern_hemi_df['Lat']
y_s_h_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_s_values, y_s_h_values)
regress_values = x_s_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(8.5, 7))
plt.scatter(x_s_values,y_s_h_values)
plt.plot(x_s_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.24282763471806626

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_n_values = northern_hemi_df['Lat']
y_n_c_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_n_values, y_n_c_values)
regress_values = x_n_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(8.5, 7))
plt.scatter(x_n_values,y_n_c_values)
plt.plot(x_n_values,regress_values,"r-")
plt.annotate(line_eq,(42,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.3020068563951419

# %%
# Southern Hemisphere
x_s_values = southern_hemi_df['Lat']
y_s_c_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_s_values, y_s_c_values)
regress_values = x_s_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(8.5, 7))
plt.scatter(x_s_values,y_s_c_values)
plt.plot(x_s_values,regress_values,"r-")
plt.annotate(line_eq,(-55,23),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.38245814768634073

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_n_values = northern_hemi_df['Lat']
y_n_w_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_n_values, y_n_w_values)
regress_values = x_n_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(8.5, 7))
plt.scatter(x_n_values,y_n_w_values)
plt.plot(x_n_values,regress_values,"r-")
plt.annotate(line_eq,(42,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.012845117738522012

# %%
# Southern Hemisphere
x_s_values = southern_hemi_df['Lat']
y_s_w_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_s_values, y_s_w_values)
regress_values = x_s_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(8.5, 7))
plt.scatter(x_s_values,y_s_w_values)
plt.plot(x_s_values,regress_values,"r-")
plt.annotate(line_eq,(-50,12),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.2604829617632001

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
